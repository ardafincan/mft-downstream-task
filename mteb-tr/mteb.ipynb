# %%
# %pip install mteb
# Out:
# Collecting mteb
#   Downloading mteb-2.6.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: datasets>=2.19.0 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from mteb) (4.4.2)
# Requirement already satisfied: numpy<3.0.0,>=1.0.0 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from mteb) (2.4.0)
# Requirement already satisfied: requests>=2.26.0 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from mteb) (2.32.5)
# Requirement already satisfied: scikit-learn>=1.4.0 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from mteb) (1.8.0)
# Requirement already satisfied: scipy>=0.0.0 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from mteb) (1.16.3)
# Requirement already satisfied: sentence_transformers>=3.0.0 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from mteb) (5.2.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from mteb) (4.15.0)
# Requirement already satisfied: torch>1.0.0 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from mteb) (2.9.1)
# Requirement already satisfied: tqdm>1.0.0 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from mteb) (4.67.1)
# Requirement already satisfied: rich>=0.0.0 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from mteb) (14.0.0)
# Collecting pytrec-eval-terrier>=0.5.6 (from mteb)
#   Downloading pytrec_eval_terrier-0.5.10-cp313-cp313-macosx_10_13_universal2.whl.metadata (1.1 kB)
# Requirement already satisfied: pydantic>=2.0.0 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from mteb) (2.11.10)
# Collecting polars>=0.20.22 (from mteb)
#   Downloading polars-1.36.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: filelock in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from datasets>=2.19.0->mteb) (3.20.1)
# Requirement already satisfied: pyarrow>=21.0.0 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from datasets>=2.19.0->mteb) (22.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from datasets>=2.19.0->mteb) (0.4.0)
# Requirement already satisfied: pandas in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from datasets>=2.19.0->mteb) (2.3.3)
# Requirement already satisfied: httpx<1.0.0 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from datasets>=2.19.0->mteb) (0.28.1)
# Requirement already satisfied: xxhash in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from datasets>=2.19.0->mteb) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from datasets>=2.19.0->mteb) (0.70.18)
# Requirement already satisfied: fsspec<=2025.10.0,>=2023.1.0 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.19.0->mteb) (2025.10.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from datasets>=2.19.0->mteb) (0.36.0)
# Requirement already satisfied: packaging in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from datasets>=2.19.0->mteb) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from datasets>=2.19.0->mteb) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.19.0->mteb) (3.13.2)
# Requirement already satisfied: anyio in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from httpx<1.0.0->datasets>=2.19.0->mteb) (4.12.0)
# Requirement already satisfied: certifi in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from httpx<1.0.0->datasets>=2.19.0->mteb) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from httpx<1.0.0->datasets>=2.19.0->mteb) (1.0.9)
# Requirement already satisfied: idna in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from httpx<1.0.0->datasets>=2.19.0->mteb) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from httpcore==1.*->httpx<1.0.0->datasets>=2.19.0->mteb) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets>=2.19.0->mteb) (1.2.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.19.0->mteb) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.19.0->mteb) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.19.0->mteb) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.19.0->mteb) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.19.0->mteb) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.19.0->mteb) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.19.0->mteb) (1.22.0)
# Collecting polars-runtime-32==1.36.1 (from polars>=0.20.22->mteb)
#   Downloading polars_runtime_32-1.36.1-cp39-abi3-macosx_11_0_arm64.whl.metadata (1.5 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from pydantic>=2.0.0->mteb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from pydantic>=2.0.0->mteb) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from pydantic>=2.0.0->mteb) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from requests>=2.26.0->mteb) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from requests>=2.26.0->mteb) (2.6.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from rich>=0.0.0->mteb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from rich>=0.0.0->mteb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=0.0.0->mteb) (0.1.2)
# Requirement already satisfied: joblib>=1.3.0 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from scikit-learn>=1.4.0->mteb) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from scikit-learn>=1.4.0->mteb) (3.6.0)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from sentence_transformers>=3.0.0->mteb) (4.57.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from transformers<6.0.0,>=4.41.0->sentence_transformers>=3.0.0->mteb) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from transformers<6.0.0,>=4.41.0->sentence_transformers>=3.0.0->mteb) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from transformers<6.0.0,>=4.41.0->sentence_transformers>=3.0.0->mteb) (0.7.0)
# Requirement already satisfied: setuptools in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from torch>1.0.0->mteb) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from torch>1.0.0->mteb) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from torch>1.0.0->mteb) (3.6.1)
# Requirement already satisfied: jinja2 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from torch>1.0.0->mteb) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from sympy>=1.13.3->torch>1.0.0->mteb) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from jinja2->torch>1.0.0->mteb) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from pandas->datasets>=2.19.0->mteb) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from pandas->datasets>=2.19.0->mteb) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from pandas->datasets>=2.19.0->mteb) (2025.3)
# Requirement already satisfied: six>=1.5 in /Users/alibayram/.pyenv/versions/3.13.3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.19.0->mteb) (1.17.0)
# Downloading mteb-2.6.1-py3-none-any.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 2.3 MB/s  0:00:02 eta 0:00:01
# Downloading polars-1.36.1-py3-none-any.whl (802 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 802.4/802.4 kB 10.0 MB/s  0:00:00
# Downloading polars_runtime_32-1.36.1-cp39-abi3-macosx_11_0_arm64.whl (39.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.3/39.3 MB 13.6 MB/s  0:00:02m0:00:0100:01
# Downloading pytrec_eval_terrier-0.5.10-cp313-cp313-macosx_10_13_universal2.whl (137 kB)
# Installing collected packages: polars-runtime-32, pytrec-eval-terrier, polars, mteb
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [mteb]3/4 [mteb]s]eval-terrier]
# Successfully installed mteb-2.6.1 polars-1.36.1 polars-runtime-32-1.36.1 pytrec-eval-terrier-0.5.10
# Note: you may need to restart the kernel to use updated packages.

# %%
import mteb
from mteb import MTEB
from sentence_transformers import SentenceTransformer

# Get the Turkish benchmark
mteb_tr = mteb.get_benchmark("MTEB(Turkish)")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 6
#       3 from sentence_transformers import SentenceTransformer
#       5 # Get the Turkish benchmark
# ----> 6 mteb_tr = mteb.get_benchmark("MTEB(Turkish)")
#
# File ~/.pyenv/versions/3.13.3/lib/python3.13/site-packages/mteb/benchmarks/get_benchmark.py:58, in get_benchmark(benchmark_name)
#      56     else:
#      57         suggestion = f"KeyError: '{benchmark_name}' not found and no similar keys were found."
# ---> 58     raise KeyError(suggestion)
#      59 return benchmark_registry[benchmark_name]
#
# KeyError: "KeyError: 'MTEB(Turkish)' not found. Did you mean: MTEB(rus, v1)?"

# %%
# Initialize your model
model = SentenceTransformer("model_name", trust_remote_code=True)

# Initialize MTEB evaluation
evaluation = MTEB(tasks=mteb_tr)

# Run evaluation
results = evaluation.run(model, output_folder="results")
